# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('Downloads/train.csv')
data
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# ...

# %%
# Mean of all numerical variables

values_1 = data['Designation'].values
average_value_1 = np.mean(values)


values_2 = data['Resource Allocation'].values
average_value_2 = np.mean(values)


values_3 = data['Mental Fatigue Score'].values
average_value_3 = np.mean(values)


values_4 = data['Burn Rate'].values
average_value_4 = np.mean(values)

print("Designation Average:", average_value_1)
print("Resource Allocation Average:", average_value_2)
print("Mental Fatigue Score Average:", average_value_3)
print("Burn Rate Average:", average_value_4)
# Out:
# Designation Average: 0.4520054563950802
# Resource Allocation Average: 0.4520054563950802
# Mental Fatigue Score Average: 0.4520054563950802
# Burn Rate Average: 0.4520054563950802

# %%
# Median of all numerical values

values = data['Designation']
median_value_1 = values.median()

values = data['Resource Allocation']
median_value_2 = values.median()

values = data['Mental Fatigue Score']
median_value_3 = values.median()

values = data['Burn Rate']
median_value_4 = values.median()

print("Designation Median:", median_value_1)
print("Resource Allocation Median:", median_value_2)
print("Mental Fatigue Score Median:", median_value_3)
print("Burn Rate Median:", median_value_4)
# Out:
# Designation Median: 2.0
# Resource Allocation Median: 4.0
# Mental Fatigue Score Median: 5.9
# Burn Rate Median: 0.45

# %%
# Mode of all variables

mode_value = data.mode().iloc[0]

print("Mode:", mode_value)
# Out:
# Mode: Employee ID               fffe3100
# Date of Joining         2008-01-06
# Gender                      Female
# Company Type               Service
# WFH Setup Available            Yes
# Designation                    2.0
# Resource Allocation            4.0
# Mental Fatigue Score           6.0
# Burn Rate                     0.47
# Name: 0, dtype: object

# %%
# Standard Deviation of numerical variables

column_values_1 = data['Designation']
column_values_2 = data['Resource Allocation']
column_values_3 = data['Mental Fatigue Score']
column_values_4 = data['Burn Rate']

std_value_1 = np.std(column_values_1)
std_value_2 = np.std(column_values_2)
std_value_3 = np.std(column_values_3)
std_value_4 = np.std(column_values_4)

print("Designation Standard Deviation:", std_value_1)
print("Resource Allocation Standard Deviation:", std_value_2)
print("Mental Fatigue Score Standard Deviation:", std_value_3)
print("Burn Rate Standard Deviation:", std_value_4)
# Out:
# Designation Standard Deviation: 1.1351197454954034
# Resource Allocation Standard Deviation: 2.047163218610548
# Mental Fatigue Score Standard Deviation: 1.920792139677332
# Burn Rate Standard Deviation: 0.19822178639142551

# %%
# Gender Disparity

column_values = data['Gender']

value_counts = column_values.value_counts()

plt.figure(figsize=(8, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Gender')
plt.show()

save_path = 'Downloads/fig_1.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Company Type Disparity

column_values = data['Company Type']

value_counts = column_values.value_counts()

plt.figure(figsize=(8, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Company Type')
plt.show()

save_path = 'Downloads/fig_2.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# WFH Setup Disparity

column_values = data['WFH Setup Available']

value_counts = column_values.value_counts()

plt.figure(figsize=(8, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('WFH')
plt.show()

save_path = 'Downloads/fig_3.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Burn Rate compared to Designation
x_values = data['Burn Rate']
y_values = data['Designation']

plt.scatter(x_values, y_values)
plt.xlabel('Burn Rate')
plt.ylabel('Designation')
plt.title('Burn Rate vs Designation')
plt.show()

save_path = 'Downloads/fig_4.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Burn Rate compared to Designation
x_values = data['Burn Rate']
y_values = data['Resource Allocation']

plt.scatter(x_values, y_values)
plt.xlabel('Burn Rate')
plt.ylabel('Resource Allocation')
plt.title('Burn Rate vs Resource Allocation')
plt.show()

save_path = 'Downloads/fig_5.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Burn Rate compared to Mental Fatigue Score
x_values = data['Burn Rate']
y_values = data['Mental Fatigue Score']

plt.scatter(x_values, y_values)
plt.xlabel('Burn Rate')
plt.ylabel('Mental Fatigue Score')
plt.title('Burn Rate vs Mental Fatigue Score')
plt.show()

save_path = 'Downloads/fig_6.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
